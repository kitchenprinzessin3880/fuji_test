# %%
import json
import requests
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['axes.grid'] = True
import pandas as pd
import seaborn as sns 
import itertools
import collections
import time
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Get info of all metrics implemented

# %%
metrics = []
try:
    request = requests.get('http://seprojects.marum.de:1071/fuji/api/v1/metrics',headers={'Content-Type': 'application/json'}, auth=('marvel2020', 'wonderwoman2020'))
    mm = request.json()['metrics']
    for m in mm:
        metrics.append({k: m[k] for k in ('metric_identifier', 'metric_name', 'total_score')})
except requests.exceptions.RequestException as e:
    print(e)
except requests.exceptions.ConnectionError as e1:
    print(e1)

# %%
df_metrics = pd.DataFrame.from_dict(metrics)
df_metrics.head(20)
# Out:
#    metric_identifier  \
# 0         FsF-F1-01D
# 1         FsF-F1-02D
# 2         FsF-F2-01M
# 3         FsF-F3-01M
# 4         FsF-F4-01M
# 5         FsF-A1-01M
# 6        FsF-A1-02MD
# 7         FsF-A2-01M
# 8         FsF-I1-01M
# 9         FsF-I1-02M
# 10        FsF-I3-01M
# 11       FsF-R1-01MD
# 12      FsF-R1.1-01M
# 13      FsF-R1.2-01M
# 14      FsF-R1.3-01M
# 15      FsF-R1.3-02D
#
#                                                                                                                                                       metric_name  \
# 0                                                                                                                  Data is assigned a globally unique identifier.
# 1                                                                                                                       Data is assigned a persistent identifier.
# 2   Metadata includes descriptive core elements (creator, title, data identifier, publisher, publication date, summary and keywords) to support data findability.
# 3                                                                                                      Metadata includes the identifier of the data it describes.
# 4                                                                                    Metadata is offered in such a way that it can be retrieved programmatically.
# 5                                                                                               Metadata contains access level and access conditions of the data.
# 6                                                      Metadata as well as data are retrievable by their identifier using a standardized communications protocol.
# 7                                                                                            Metadata remains available, even if the data is no longer available.
# 8                                                                                       Metadata is represented using a formal knowledge representation language.
# 9                                                                                                                                Metadata uses semantic resources
# 10                                                                                             Metadata includes links between the data and its related entities.
# 11                                                                                                                    Metadata specifies the content of the data.
# 12                                                                                          Metadata includes license information under which data can be reused.
# 13                                                                                    Metadata includes provenance information about data creation or generation.
# 14                                                                          Metadata follows a standard recommended by the target research community of the data.
# 15                                                                               Data is available in a file format recommended by the target research community.
#
#     total_score
# 0             1
# 1             1
# 2             2
# 3             1
# 4             2
# 5             1
# 6             2
# 7             1
# 8             2
# 9             1
# 10            1
# 11            4
# 12            1
# 13            2
# 14            1
# 15            1

# %% [markdown]
# # Run FAIR assessment for a given identifier

# %%
identifier = 'https://doi.org/10.1594/PANGAEA.897578'

# %%
# %%time
fuji_service = 'http://localhost:1071/fuji/api/v1/evaluate'
req = {'object_identifier':identifier, 'test_debug':True}
r = requests.post(fuji_service, data=json.dumps(req), headers={'Content-Type': 'application/json'}, auth=('username', 'password'))
json_data = r.json()
# Out:
# Wall time: 4.74 s

# %%
json_data
# Out:
# [{'id': 1,
#   'metric_identifier': 'FsF-F1-01D',
#   'metric_name': 'Data is assigned a globally unique identifier.',
#   'output': {'guid': 'https://doi.org/10.1594/PANGAEA.897578',
#    'guid_scheme': 'doi'},
#   'score': {'earned': 1, 'total': 1},
#   'test_debug': ["INFO: Unique identifier schemes found ['doi', 'url']",
#    'INFO: Finalized unique identifier scheme - doi'],
#   'test_status': 'pass'},
#  {'id': 2,
#   'metric_identifier': 'FsF-F1-02D',
#   'metric_name': 'Data is assigned a persistent identifier.',
#   'output': {'pid': 'https://doi.org/10.1594/PANGAEA.897578',
#    'pid_scheme': 'doi',
#    'resolvable_status': True,
#    'resolved_url': 'https://doi.pangaea.de/10.1594/PANGAEA.897578'},
#   'score': {'earned': 1, 'total': 1},
#   'test_debug': ['INFO: Persistence identifier scheme - doi',
#    'INFO: Retrieving page http://doi.org/10.1594/PANGAEA.897578',
#    'INFO: Content negotiation accept=text/html, application/xhtml+xml, status=200',
#    'INFO: Found HTML page!',
#    'INFO: Object identifier active (status code = 200)'],
#   'test_status': 'pass'},
#  {'id': 3,
#   'metric_identifier': 'FsF-F2-01M',
#   'metric_name': 'Metadata includes descriptive core elements (creator, title, data identifier, publisher, publication date, summary and keywords) to support data findability.',
#   'output': {'core_metadata_found': {'creator': ['Jean-Louis Bonne',
#      'Martin Werner',
#      'Hanno Meyer',
#      'Sepp Kipfstuhl',
#      'Benjamin Rabe',
#      'Melanie K Behrens',
#      'Lutz Schönicke',
#      'Hans Christian Steen-Larsen',
#      'Stefanie Arndt',
#      'Stephanie Bohlmann',
#      'Elke Burkhardt',
#      'Ronny Engelmann',
#      'Michael Flau',
#      'Julia Goedecke',
#      'Moritz Haarig',
#      'Hendrik Hampe',
#      'Céline Heuzé',
#      'Mario Hoppmann',
#      'Myriel Horn',
#      'Heike Kalesse',
#      'Lester Lembke-Jene',
#      'Anna Nikolopoulos',
#      'Leonard Rossmann',
#      'Vera Schlindwein',
#      'Bermann Steinmacher',
#      'Sandra Tippenhauer',
#      'Ole Valk'],
#     'object_identifier': 'https://doi.org/10.1594/PANGAEA.897578',
#     'publication_date': '2019-01-23',
#     'publisher': 'PANGAEA',
#     'summary': 'Here, we present a new isotopic dataset of near-surface water vapour and oceanic surface water continuously surveyed from the Polarstern research vessel during a period of two years from 2015-06-29 to 2017-07-01. The dataset covers areas spanning from the North Pole to the coasts of Antarctica in the Atlantic sector. Water vapour observations have been measured continuously on-board using a Cavity Ring-Down Spectrometer from a 29 m elevation above the sea level. The oceanic water has been sampled on a daily basis and later analyzed for water isotopic composition at the Alfred Wegener Institut laboratory in Potsdam, Germany. […]',
#     'title': 'Near-surface atmospheric vapour and oceanic surface water isotopic compositions calibrated data from Polarstern cruises, 2015-2017'},
#    'core_metadata_source': ['Schema.org JSON-LD (Embedded)',
#     'Embedded DublinCore',
#     'Datacite Search'],
#    'core_metadata_status': 'partial metadata'},
#   'score': {'earned': 1, 'total': 2},
#   'test_debug': ["INFO: Formats of structured metadata embedded in HTML markup dict_keys(['json-ld', 'opengraph', 'microformat', 'rdfa'])",
#    'INFO: Extract metadata from Schema.org JSON-LD (Embedded)',
#    'INFO: Extract DublinCore metadata from html page',
#    'INFO: Retrieving page https://doi.pangaea.de/10.1594/PANGAEA.897578',
#    'INFO: Content negotiation accept=application/xml, text/xml;q=0.5, status=406',
#    'WARNING: NO successful response received, status code - 406',
#    'INFO: Extract metadata from Generic XML (Negotiated)',
#    'INFO: Expected XML but content negotiation responded: html',
#    'INFO: Extract datacite metadata',
#    'INFO: Retrieving page http://doi.org/10.1594/PANGAEA.897578',
#    'INFO: Content negotiation accept=application/vnd.datacite.datacite+json, status=200',
#    'INFO: Extract metadata from Linked Data (RDF)',
#    'INFO: Retrieving page https://doi.pangaea.de/10.1594/PANGAEA.897578',
#    'INFO: Content negotiation accept=text/turtle, application/turtle, application/x-turtle;q=0.8, application/rdf+xml, text/n3;q=0.9, text/rdf+n3;q=0.9, status=406',
#    'WARNING: NO successful response received, status code - 406',
#    'INFO: Expected RDF Graph but received - text/html',
#    'INFO: Linked Data metadata UNAVAILABLE',
#    'INFO: Type of object described by the metadata - Dataset',
#    "INFO: Required core metadata ['creator', 'title', 'publisher', 'publication_date', 'summary', 'keywords', 'object_identifier']",
#    "WARNING: Missing core metadata ['keywords']"],
#   'test_status': 'pass'},
#  {'id': 4,
#   'metric_identifier': 'FsF-F3-01M',
#   'metric_name': 'Metadata includes the identifier of the data it describes.',
#   'output': {'content': [{'content_identifier_active': True,
#      'content_identifier_included': {'header_content_length': None,
#       'header_content_type': 'application/zip',
#       'size': '23.0 datasets',
#       'type': 'application/zip',
#       'url': 'https://doi.pangaea.de/10.1594/PANGAEA.897578?format=zip'}}],
#    'object_identifier_included': 'https://doi.org/10.1594/PANGAEA.897578'},
#   'score': {'earned': 1, 'total': 1},
#   'test_debug': ['INFO: Object identifier specified https://doi.org/10.1594/PANGAEA.897578',
#    'INFO: Number of object content identifier found - 1'],
#   'test_status': 'pass'},
#  {'id': 5,
#   'metric_identifier': 'FsF-F4-01M',
#   'metric_name': 'Metadata is offered in such a way that it can be retrieved programmatically.',
#   'output': {'search_mechanisms': [{'mechanism': 'structured data',
#      'mechanism_info': ['Schema.org JSON-LD (Embedded)',
#       'Embedded DublinCore']},
#     {'mechanism': 'metadata registry',
#      'mechanism_info': ['Datacite Search']}]},
#   'score': {'earned': 2, 'total': 2},
#   'test_debug': ["INFO: Supported tests of metadata retrieval/extraction - 'Embedded DublinCore', 'Embedded OpenGraph', 'Schema.org JSON-LD (Embedded)', 'Schema.org JSON-LD (Negotiated)', 'Datacite Search', 'Signposting Typed Links', 'RDF-based Typed Links', 'Linked Data (RDF)', 'B2FIND Metadata Aggregator', 'Guessed XML Link', 'Generic XML (Negotiated)'",
#    'INFO: Metadata found through - structured data',
#    'INFO: Metadata found through - metadata registry'],
#   'test_status': 'pass'},
#  {'id': 6,
#   'metric_identifier': 'FsF-A1-01M',
#   'metric_name': 'Metadata contains access level and access conditions of the data.',
#   'output': {'access_details': {'access_condition': 'unrestricted',
#     'accessible_free': True},
#    'access_level': 'public'},
#   'score': {'earned': 1, 'total': 1},
#   'test_debug': ['INFO: Found access rights information in dedicated metadata element',
#    'INFO: Access information specified - unrestricted',
#    'INFO: Search license SPDX details by name - unrestricted',
#    'INFO: Not a standardized access level',
#    "INFO: Used 'schema.org/isAccessibleForFree' to determine the access level (either public or restricted)"],
#   'test_status': 'pass'},
#  {'id': 7,
#   'metric_identifier': 'FsF-I1-01M',
#   'metric_name': 'Metadata is represented using a formal knowledge representation language.',
#   'output': [{'is_metadata_found': True,
#     'serialization_format': 'JSON-LD',
#     'source': 'structured_data'}],
#   'score': {'earned': 1, 'total': 2},
#   'test_debug': ['INFO: Check of structured data (RDF serialization) embedded in the data page',
#    'INFO: RDF Serialization found in the data page - JSON-LD',
#    'INFO: Check if RDF-based typed link included',
#    'INFO: NO RDF-based typed link found',
#    'INFO: Check if RDF metadata available through content negotiation',
#    'INFO: NO RDF metadata available through content negotiation',
#    'WARNING: NO SPARQL endpoint found through re3data based on the object URI provided'],
#   'test_status': 'pass'},
#  {'id': 8,
#   'metric_identifier': 'FsF-I1-02M',
#   'metric_name': 'Metadata uses semantic resources',
#   'output': [{'is_namespace_active': True, 'namespace': 'http://schema.org/'}],
#   'score': {'earned': 1, 'total': 1},
#   'test_debug': ['INFO: Number of vocabulary namespaces extracted from all RDF-based metadata - 2',
#    "INFO: Default vocabulary namespace(s) excluded - ['http://purl.org/dc/elements/1.1/']",
#    "INFO: Check the remaining namespace(s) exists in LOD - ['http://schema.org/']",
#    "INFO: Namespace matches found - ['http://schema.org/']"],
#   'test_status': 'pass'},
#  {'id': 9,
#   'metric_identifier': 'FsF-I3-01M',
#   'metric_name': 'Metadata includes links between the data and its related entities.',
#   'output': [{'related_resource': 'https://doi.org/10.1038/s41467-019-09242-6',
#     'relation_type': 'isBasedOn'},
#    {'related_resource': 'Supplement to: Bonne, Jean-Louis; Behrens, Melanie K; Meyer, Hanno; Kipfstuhl, Sepp; Rabe, Benjamin; Schönicke, Lutz; Steen-Larsen, Hans Christian; Werner, Martin (2019): Resolving the controls of water vapour isotopes in the Atlantic sector. Nature Communications, 10(1), https://doi.org/10.1038/s41467-019-09242-6',
#     'relation_type': 'isBasedOn'},
#    {'related_resource': 'Dataset description (URI: https://store.pangaea.de//Publications/BonneJL-etal_2019/BonneJL-etal_description.pdf)',
#     'relation_type': 'isRelatedTo'},
#    {'relatedIdentifier': '10.1038/s41467-019-09242-6',
#     'relatedIdentifierType': 'DOI',
#     'relationType': 'IsSupplementTo'},
#    {'relatedIdentifier': 'https://store.pangaea.de//Publications/BonneJL-etal_2019/BonneJL-etal_description.pdf',
#     'relatedIdentifierType': 'URL',
#     'relationType': 'IsDocumentedBy'}],
#   'score': {'earned': 1, 'total': 1},
#   'test_debug': ['INFO: 1 related resource(s) extracted from Schema.org JSON-LD (Embedded)',
#    'INFO: 2 related resource(s) extracted from Embedded DublinCore',
#    'INFO: 2 related resource(s) extracted from Datacite Search',
#    'INFO: Total number of related resources extracted - 5',
#    'INFO: Number of related resources after QC step - 5'],
#   'test_status': 'pass'},
#  {'id': 10,
#   'metric_identifier': 'FsF-R1-01MD',
#   'metric_name': 'Metadata specifies the content of the data.',
#   'output': {'data_content_descriptor': [{'descriptor': 'file type',
#      'descriptor_value': 'application/zip',
#      'matches_content': True},
#     {'descriptor': 'file size',
#      'descriptor_value': '23.0 datasets',
#      'matches_content': True}],
#    'object_type': 'Dataset'},
#   'score': {'earned': 3, 'total': 4},
#   'test_debug': ['INFO: Object landing page accessible status - True',
#    'INFO: Resource type specified - Dataset',
#    'INFO: Number of data content URI(s) specified - 1',
#    'INFO: Selected content file to be analyzed - https://doi.pangaea.de/10.1594/PANGAEA.897578?format=zip',
#    'INFO: File request status code 200',
#    'INFO: Succesfully parsed data file(s) - ["b\'10.1594-pangaea.897578\'", \'datasets/PS96_water_vapour_stable_isotopes.tab\', \'datasets/PS104_water_vapour_stable_isotopes.tab\', \'datasets/PS95.1_water_vapour_stable_isotopes.tab\', \'datasets/PS95.2_water_vapour_stable_isotopes.tab\', \'datasets/PS98_water_vapour_stable_isotopes.tab\', \'datasets/PS105_water_vapour_stable_isotopes.tab\', \'datasets/PS102_water_vapour_stable_isotopes.tab\', \'datasets/PS103_water_vapour_stable_isotopes.tab\', \'datasets/PS94_water_vapour_stable_isotopes.tab\', \'datasets/PS101_water_vapour_stable_isotopes.tab\', \'datasets/PS97_water_vapour_stable_isotopes.tab\', \'datasets/PS106_water_vapour_stable_isotopes.tab\', \'datasets/PS100_water_vapour_stable_isotopes.tab\', \'datasets/PS93.2_water_vapour_stable_isotopes.tab\', \'datasets/PS99.1_water_vapour_stable_isotopes.tab\', \'datasets/PS99.2_water_vapour_stable_isotopes.tab\', \'datasets/PS93.1_water_vapour_stable_isotopes.tab\', \'datasets/Tromsø_Port_water_vapour_stable_isotopes.tab\', \'datasets/Troms_Port_2015-08_water_vapour_stable_isotopes.tab\', \'datasets/Bremerhaven_LloydWerft_water_vapour_stable_isotopes.tab\', \'datasets/Bremerhaven_LloydWerft_water_vapour_stable_isotopes_2.tab\', \'datasets/Cape_Town_Harbour_water_vapour_stable_isotopes.tab\', \'datasets/Bremerhaven_LloydWerft_water_vapour_stable_isotopes_3.tab\', \'summary.txt\']',
#    "WARNING: NO measured variables found in metadata, skip 'measured_variable' test."],
#   'test_status': 'pass'},
#  {'id': 11,
#   'metric_identifier': 'FsF-R1.1-01M',
#   'metric_name': 'Metadata includes license information under which data can be reused.',
#   'output': [{'details_url': 'http://spdx.org/licenses/CC-BY-4.0.html',
#     'license': 'https://creativecommons.org/licenses/by/4.0/',
#     'osi_approved': False}],
#   'score': {'earned': 1, 'total': 1},
#   'test_debug': ['INFO: Search license SPDX details by url - https://creativecommons.org/licenses/by/4.0/',
#    'INFO: Found SPDX license representation - http://spdx.org/licenses/CC-BY-4.0.json'],
#   'test_status': 'pass'},
#  {'id': 12,
#   'metric_identifier': 'FsF-R1.2-01M',
#   'metric_name': 'Metadata includes provenance information about data creation or generation.',
#   'output': {'provenance_metadata_included': {'is_available': True,
#     'provenance_metadata': [{'metadata_element': 'publication_date',
#       'metadata_value': '2019-01-23',
#       'prov_o_mapping': 'prov:generatedAtTime'},
#      {'metadata_element': 'creator',
#       'metadata_value': ['Jean-Louis Bonne',
#        'Martin Werner',
#        'Hanno Meyer',
#        'Sepp Kipfstuhl',
#        'Benjamin Rabe',
#        'Melanie K Behrens',
#        'Lutz Schönicke',
#        'Hans Christian Steen-Larsen',
#        'Stefanie Arndt',
#        'Stephanie Bohlmann',
#        'Elke Burkhardt',
#        'Ronny Engelmann',
#        'Michael Flau',
#        'Julia Goedecke',
#        'Moritz Haarig',
#        'Hendrik Hampe',
#        'Céline Heuzé',
#        'Mario Hoppmann',
#        'Myriel Horn',
#        'Heike Kalesse',
#        'Lester Lembke-Jene',
#        'Anna Nikolopoulos',
#        'Leonard Rossmann',
#        'Vera Schlindwein',
#        'Bermann Steinmacher',
#        'Sandra Tippenhauer',
#        'Ole Valk'],
#       'prov_o_mapping': 'prov:wasAttributedTo'},
#      {'metadata_element': 'publisher',
#       'metadata_value': 'PANGAEA',
#       'prov_o_mapping': 'prov:wasAttributedTo'},
#      {'metadata_element': 'related.isBasedOn',
#       'metadata_value': 'https://doi.org/10.1038/s41467-019-09242-6',
#       'prov_o_mapping': 'prov:hadPrimarySource'}]},
#    'structured_provenance_available': {'is_available': False,
#     'provenance_metadata': []}},
#   'score': {'earned': 1, 'total': 2},
#   'test_debug': ['INFO: Found data creation-related provenance information',
#    'WARNING: Formal provenance metadata is unavailable'],
#   'test_status': 'pass'},
#  {'id': 13,
#   'metric_identifier': 'FsF-R1.3-01M',
#   'metric_name': 'Metadata follows a standard recommended by the target research community of the data.',
#   'output': [{'metadata_standard': 'DIF - Directory Interchange Format',
#     'subject_areas': ['Agriculture',
#      'Biochemistry',
#      'Climatology',
#      'Ecology',
#      'Glaciology',
#      'Hydrology',
#      'Marine biology',
#      'Meteorology',
#      'Oceanography'],
#     'urls': ['http://gcmd.nasa.gov/add/difguide/WRITEADIF.pdf',
#      'http://gcmd.nasa.gov/add/difguide/']},
#    {'metadata_standard': 'ISO 19115',
#     'subject_areas': ['Cartography',
#      'Climatology',
#      'Earth sciences',
#      'Geography',
#      'Geology',
#      'Glaciology',
#      'Hydrogeology',
#      'Hydrology',
#      'Meteorology',
#      'Oceanography',
#      'Topography'],
#     'urls': ['http://standards.iso.org/iso/19115/-3/',
#      'http://www.iso.org/iso/catalogue_detail.htm?csnumber=53798']},
#    {'metadata_standard': 'Darwin Core',
#     'subject_areas': ['Biogeography',
#      'Biological diversity',
#      'Botany',
#      'Cartography',
#      'Earth sciences',
#      'Ecology',
#      'Marine animals',
#      'Oceanography',
#      'Palaeontology',
#      'Physical geography',
#      'Topography',
#      'Zoology'],
#     'urls': ['http://www.tdwg.org/standards/450',
#      'http://rs.tdwg.org/dwc/index.htm']}],
#   'score': {'earned': 1, 'total': 1},
#   'test_debug': ['INFO: Retrieving API and Standards from R3DATA',
#    'INFO: R3DATA/Datacite client id - pangaea.repository',
#    'INFO: Skipping non-disciplinary standard listed in OAIPMH - Dublin Core'],
#   'test_status': 'pass'},
#  {'id': 14,
#   'metric_identifier': 'FsF-R1.3-02D',
#   'metric_name': 'Data is available in a file format recommended by the target research community.',
#   'output': [{'file_uri': 'https://doi.pangaea.de/10.1594/PANGAEA.897578?format=zip',
#     'is_preferred_format': True,
#     'mime_type': 'text/tsv',
#     'preference_reason': ['long term format',
#      'open format',
#      'generic science format'],
#     'subject_areas': ['General']},
#    {'file_uri': 'https://doi.pangaea.de/10.1594/PANGAEA.897578?format=zip',
#     'is_preferred_format': True,
#     'mime_type': 'text/plain',
#     'preference_reason': ['long term format',
#      'open format',
#      'generic science format'],
#     'subject_areas': ['General']}],
#   'score': {'earned': 1, 'total': 1},
#   'test_debug': ["INFO: Object content identifier provided - ['https://doi.pangaea.de/10.1594/PANGAEA.897578?format=zip']",
#    'WARNING: Archiving/compression format specified - application/zip',
#    "INFO: Extracted file formats - ['text/tsv', 'text/plain']"],
#   'test_status': 'pass'}]

# %%
def process_json(json_data):
    earned = collections.OrderedDict()
    totals = collections.OrderedDict()
    principle_totals =  collections.OrderedDict()

    for d in json_data:
        metric_identifier = d['metric_identifier']
        sub_principle = metric_identifier.split('-')[1]
        if not sub_principle in earned:
            earned[sub_principle] = d['score']['earned']
            totals[sub_principle] = d['score']['total']
        else:
            earned[sub_principle] += d['score']['earned']
            totals[sub_principle] += d['score']['total']
         
        main_principle = sub_principle[0]
        if main_principle in principle_totals:
            principle_totals[main_principle] = principle_totals[main_principle]  + d['score']['total']
        else:
            principle_totals[main_principle] = d['score']['total']
    
    earned_arr=list(earned.values())
    total_arr=list(totals.values())
    labels=list(earned.keys())
    
    return earned_arr,total_arr,principle_totals, labels

# %%
process_json(json_data) #earned_arr,total_arr,labels
# Out:
# ([2, 1, 1, 2, 1, 2, 1, 3, 1, 1, 2],
#  [2, 2, 1, 2, 1, 3, 1, 4, 1, 2, 2],
#  OrderedDict([('F', 7), ('A', 1), ('I', 4), ('R', 9)]),
#  ['F1', 'F2', 'F3', 'F4', 'A1', 'I1', 'I3', 'R1', 'R1.1', 'R1.2', 'R1.3'])

# %%
def color_generator(colormap,earned_arr,total_arr,labels,opacity=True):
    '''
     DESCRIPTION
         generate colors for inner (F1,F2,I1,R1,..) and outer ring (F,A,I,R) of pie chart 
     INPUT
         main_dict - dictionary, with several 1st level keys F,A,I,R value 
                     of each key is a dictionary itself, containing corresponding 2nd level elements 
         col_index1 (integer) - defines the width of outer ring colorband
     OUTPUT
         colors - dictionary with mapped colors 
    '''
    if opacity:
        percentages=[earned_arr[i]/total_arr[i] for i in range(len(total_arr))]
        percentages
    else:
        percentages=[1 for i in range(len(total_arr))]
    
    col_index1=50
    #get number of nececessary colors corresponding to 
    # number of 2nd level elements (F1,F2,..) for every 1st level element (F)
    ncolors=[]
    
    for key in ['F','A','I','R']:
        count=0
        for i in range(len(labels)):
            if key in labels[i]:
                count+=1
        ncolors.append(count)
    
    # generate outer colors 
    n_inner_colors=4
    cmap = plt.get_cmap(colormap)
    inner_colors=np.arange(1,n_inner_colors+1)*col_index1
    inner_colors_mapped=cmap(inner_colors)
    
    # generate inner colors based on outer colors 
    outer_colors=[]
    for i in range(n_inner_colors):
        color_arr=np.arange(ncolors[i])*0+inner_colors[i]
        outer_colors.append(color_arr)
        
    outer_arr=np.concatenate(outer_colors)  
    outer_arr_mapped=cmap(outer_arr)
    outer_arr_mapped[:,3]=percentages
    
    return inner_colors_mapped,outer_arr_mapped

# %%
###############
# Main function
###############

def metrics_pie_plot(json_data, color_code):
    '''
    DECSRIPTION
        processes input data, then plots the pie chart for FAIR metrics
    INPUT
        results dictionary,containing processed json data (dataset metrics)
        main_keys - list, contatining main metrics names e.g. ['F','A','I','R']
    OUTPUT
        ax - matplotlib.axes._subplots.AxesSubplot object 
    '''
    
    earned_arr,total_arr,principles_dict, labels=process_json(json_data)
    # generate colors for inner (F1,F2,I1,R1,..) and outer ring (F,A,I,R) of pie chart
    inner_colors,outer_colors=color_generator(color_code,earned_arr,total_arr,labels,opacity=True)

    #PLOTTING
    fig, ax = plt.subplots(figsize=(8,8))
    size = 0.31
    
    if 0 in earned_arr:
        wedge = dict(width=size, edgecolor='grey')
    else:
        wedge = dict(width=size, edgecolor='w')
        
    # OUTER RING
    patches, texts = ax.pie(total_arr, radius=1.1, colors=outer_colors,labels=labels,
           labeldistance=0.8,wedgeprops=wedge,counterclock=False,
           startangle=90,rotatelabels=True)
    for t in texts:
        t.set_color('black')
        t.set_fontsize(13)
        #t.set_weight('bold')
    
    PRINCIPLES_DICT = {'F':'Findability','A':'Accessibility','I':'Interoperability','R':'Reusability'}
    
    # MIDDLE RING2
    #inner_colors,outer_colors=color_generator(color_code,earned_arr,total_arr,labels=labels,opacity=False)
    #ax.pie(total_arr, radius=0.75, colors=outer_colors,
           #labeldistance=0.7,wedgeprops=dict(width=size, edgecolor='w'),counterclock=False,startangle=90,rotatelabels=True)
    
    #INNER RING
    patches1, texts1 = ax.pie(principles_dict.values(), radius=0.75, colors=inner_colors,labels=PRINCIPLES_DICT.keys(),
                              labeldistance=0.8, wedgeprops=dict(width=size, edgecolor='w'),counterclock=False,startangle=90)
    

    # increase the size of the labels
    for txt in texts1:
        txt.set_color('black')
        txt.set_fontsize(18)
    
    #add legend
    plt.legend(patches, labels,fontsize="x-large",loc="upper right",bbox_to_anchor=(1.2,0.8))

    return ax

# %%
metrics_pie_plot(json_data, 'rainbow')
# Set aspect ratio to be equal so that pie is drawn as a circle.
plt.axis('equal')
plt.title("Data Object FAIRness Badge\n"+ identifier,fontsize=20)
plt.show()
